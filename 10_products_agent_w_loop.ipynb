# %%
from dotenv import load_dotenv
import os
import groq

load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 from dotenv import load_dotenv
#       2 import os
# ----> 3 import groq
#       5 load_dotenv()
#
# File c:\Users\mrcra\Desktop\conf42-ai-agents\groq.py:4
#       1 #set GROQ_API_KEY in the secrets
#       3 import os
# ----> 4 from groq import Groq
#       6 # Create the Groq client
#
# ImportError: cannot import name 'Groq' from partially initialized module 'groq' (most likely due to a circular import) (c:\Users\mrcra\Desktop\conf42-ai-agents\groq.py)

# %%
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

chat_completion = client.chat.completions.create(
    messages=[{"role": "user", "content": "What is an AI Swarm?"}],
    model="llama3-8b-8192",
    temperature=0,
)

print(chat_completion.choices[0].message.content)
# Out:
# An AI swarm is a collective of artificial intelligence (AI) systems that work together to achieve a common goal or solve a complex problem. The term "swarm" refers to the decentralized and autonomous nature of these AI systems, which operate independently but coordinate with each other to achieve a shared objective.
#
# In an AI swarm, individual AI agents or nodes communicate with each other and adapt to their environment in real-time, using algorithms and machine learning techniques to make decisions and take actions. This collective behavior allows AI swarms to exhibit emergent properties, such as self-organization, adaptability, and resilience, which are not typically found in individual AI systems.
#
# AI swarms can be applied to a wide range of domains, including:
#
# 1. Robotics: AI swarms can be used to control and coordinate multiple robots to perform tasks such as search and rescue, environmental monitoring, or surveillance.
# 2. Autonomous vehicles: AI swarms can be used to coordinate the movement and behavior of multiple autonomous vehicles, such as drones or self-driving cars.
# 3. Cybersecurity: AI swarms can be used to detect and respond to cyber threats by analyzing network traffic and coordinating with other AI systems to take action.
# 4. Healthcare: AI swarms can be used to analyze medical data and coordinate treatment plans for patients with complex conditions.
# 5. Finance: AI swarms can be used to analyze market trends and coordinate trading decisions for financial institutions.
#
# The benefits of AI swarms include:
#
# 1. Scalability: AI swarms can be easily scaled up or down depending on the complexity of the task or the amount of data to be processed.
# 2. Flexibility: AI swarms can be applied to a wide range of domains and can adapt to changing environments and requirements.
# 3. Resilience: AI swarms can continue to function even if individual nodes fail or are compromised.
# 4. Improved decision-making: AI swarms can combine the strengths of individual AI systems to make more accurate and informed decisions.
#
# However, AI swarms also present some challenges, such as:
#
# 1. Complexity: AI swarms can be difficult to design, implement, and maintain due to the complexity of the interactions between individual nodes.
# 2. Security: AI swarms can be vulnerable to attacks and data breaches if individual nodes are compromised.
# 3. Explainability: AI swarms can be difficult to explain and understand due to the emergent behavior of the collective.
#
# Overall, AI swarms have the potential to revolutionize many industries and domains by enabling the development of more sophisticated, adaptive, and resilient AI systems.

# %%
class Agent:
    def __init__(self, client: Groq, system: str = "") -> None:
        self.client = client
        self.system = system
        self.messages: list = []
        if self.system:
            self.messages.append({"role": "system", "content": system})

    def __call__(self, message=""):
        if message:
            self.messages.append({"role": "user", "content": message})
            result = self.execute()
            self.messages.append({"role": "assistant", "content": result})
            return result
        else:
            print("NO MESSAGE")

    def execute(self):
        completion = client.chat.completions.create(
            model="llama3-70b-8192", messages=self.messages
        )
        return completion.choices[0].message.content

# %%
system_prompt = """
You run in a loop of THOUGHT, ACTION, OBSERVATION.
When you have a THOUGHT you return the THOUGHT and ACTION
At the end of the loop you output an ANSWER
Use THOUGHT to describe your THOUGHTS about the question you have been asked.
Use ACTION to run one of the ACTIONS available to you - then return PAUSE.
OBSERVATION will be the result of running those ACTIONS.

Your available ACTIONS are:

# calculate_total:
if amount = 200
then calculate_total(amount)

This returns amount * 1.2

Runs the calculate_total function and returns a JSON FORMAT output as follows:
{"result": 240, "fn": "calculate_total", "next": "PAUSE"}

# get_product_price:

This uses the get_product_price function and passes in the value of the product
e.g. get_product_price('bike')

This uses the get_product_price with a product = 'bike', finds the price of the bike and then returns a JSON FORMAT output as follows:
{"result": 200, "fn": "get_product_price", "next": "PAUSE"}

Example session:

Question: What is total cost of a bike including VAT?
THOUGHT: I need to find the cost of a bike|ACTION|get_product_price|bike

You will be called again with this:

OBSERVATION|200

THOUGHT: I need to calculate the total including the VAT|ACTION|calculate_total|200

You will be called again with this: 

OBSERVATION|240

If you have the ANSWER, output it as the ANSWER.

ANSWER|The price of the bike including VAT is 240

Now it's your turn:
""".strip()


def calculate_total(amount):
    amount = int(amount)
    return int(amount * 1.2)


def get_product_price(product):
    if product == "bike":
        return 100
    if product == "tv":
        return 200
    if product == "laptop":
        return 300

    return None

# %%
# We now loop over the query until an answer is found or the'max_iterations' is reached

answers = []


def loop(max_iterations=10, query: str = ""):
    agent = Agent(client=client, system=system_prompt)
    tools = ["calculate_total", "get_product_price"]
    next_prompt = query
    i = 0
    while i < max_iterations:
        i += 1
        result = agent(next_prompt)
        if "ACTION" in result:

            next = result.split("|")
            print(next)
            next_function = next[2].strip()
            next_arg = str(next[3]).strip()

            if next_function in tools:
                result_tool = eval(f"{next_function}('{next_arg}')")
                next_prompt = f"OBSERVATION: {result_tool}"
                print(next_prompt)
            else:
                next_prompt = "OBSERVATION: Tool not found"
            continue

        if "ANSWER" in result:
            # the result at top has final result
            print(f"Answer found:\n\t{result}")
            answers.append(result)
            break


loop(query="What is cost of a bike including VAT?")
loop(query="What is cost of a tv including VAT?")
loop(query="What is cost of a laptop including VAT?")


print("\n=========== SUMMARY ANSWERS ===========")

for answer in answers:
    print(answer)
# Out:
# ['THOUGHT: I need to find the cost of a bike', 'ACTION', 'get_product_price', 'bike']
# OBSERVATION: 100
# ['THOUGHT: I need to calculate the total including the VAT, but the price is less than 200', 'ACTION', 'calculate_total', '100']
# OBSERVATION: 120
# Answer found:
# 	THOUGHT: I have calculated the total including the VAT|ANSWER|The price of the bike including VAT is 120
# ['THOUGHT: I need to find the cost of a tv', 'ACTION', 'get_product_price', 'tv']
# OBSERVATION: 200
# ['THOUGHT: I need to calculate the total including the VAT', 'ACTION', 'calculate_total', '200']
# OBSERVATION: 240
# Answer found:
# 	ANSWER|The price of the tv including VAT is 240
# ['THOUGHT: I need to find the cost of a laptop', 'ACTION', 'get_product_price', 'laptop']
# OBSERVATION: 300
# ['THOUGHT: I need to calculate the total including the VAT', 'ACTION', 'calculate_total', '300']
# OBSERVATION: 360
# Answer found:
# 	ANSWER|The price of the laptop including VAT is 360
#
# =========== SUMMARY ANSWERS ===========
# THOUGHT: I have calculated the total including the VAT|ANSWER|The price of the bike including VAT is 120
# ANSWER|The price of the tv including VAT is 240
# ANSWER|The price of the laptop including VAT is 360
